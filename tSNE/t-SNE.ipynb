# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_digits, load_iris
from sklearn.preprocessing import StandardScaler
from sklearn.manifold import TSNE
from tsne import tsne
import seaborn as sns

# %% [markdown]
# # Load Digit Datset

# %%
digits = load_digits()

# %% [markdown]
# # Try sklearn's TSNE

# %%
tsne_sk = TSNE(n_components=2, perplexity=30, random_state=17)

# %%
x_tsne = tsne_sk.fit_transform(digits.data)

# %%
def plot_tsne(X, y):
    fig = plt.figure(1, figsize=(8, 8))
    plt.scatter(X[:, 0], X[:, 1],
            c=y, edgecolor='none', alpha=0.5,
            cmap=plt.cm.get_cmap('tab10', 10))
    plt.xlabel('component 1')
    plt.ylabel('component 2')
    plt.colorbar()
    plt.show();

# %%
plot_tsne(x_tsne, digits.target)

# %%
import pandas as pd

# %%
df = pd.DataFrame(columns=['1', '2', 'target'])
df['1'] = x_tsne[:, 0]
df['2'] = x_tsne[:, 1]
df['target'] = digits.target

# %%
plt.figure(figsize=(8, 8))
sns.scatterplot(
    x='1', y='2',
    hue='target',
    palette=sns.color_palette("hls", 10),
    data=df,
    legend="full",
    alpha=0.3
)

# %% [markdown]
# # Our Implementation

# %%
tsne_my = tsne(n_components=2, perplexity=30, random_seed=17)

# %%
x_tsne_my = tsne_my.fit_transform(digits.data)

# %%
plot_tsne(x_tsne_my, digits.target)

# %%
df = pd.DataFrame(columns=['1', '2', 'target'])
df['1'] = x_tsne_my[:, 0]
df['2'] = x_tsne_my[:, 1]
df['target'] = digits.target

# %%
plt.figure(figsize=(8, 8))
sns.scatterplot(
    x='1', y='2',
    hue='target',
    palette=sns.color_palette("hls", 10),
    data=df,
    legend="full",
    alpha=0.3
)
